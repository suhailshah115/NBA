# %% [markdown]
# # NBA Exploratory Data Analysis

# %% [markdown]
# The National Basketball Association (NBA) is a professional basketball league in Northern America composed of 30 teams (29 in the United States and 1 in Canada). It is one of the major professional sports leagues in the United States and Canada and is considered the premier men's professional basketball league in the world.
#
# The league was founded in New York City on June 6, 1946, as the Basketball Association of America (BAA).It changed its name to the National Basketball Association on August 3, 1949, after merging with the competing National Basketball League (NBL). In 1976, the NBA and the American Basketball Association (ABA) merged, adding four franchises to the NBA. The NBA's regular season runs from October to April, with each team playing 82 games. The league's playoff tournament extends into June. As of 2020, NBA players are the world's best paid athletes by average annual salary per player.

# %% [markdown]
# Importing Neccessary Libraies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# We have Three data sets:
# 1. NBA_season1718_salary.csv.
# 2.player_data.csv.
# 3.Seasons_Stats.csv

# %% [markdown]
# # # Reading the data

# %%
df1 = pd.read_csv('player_data.csv')

# %%
df1.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
df2 = pd.read_csv('NBA_season1718_salary.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0          Player   Tm  season17_18
# 0           1   Stephen Curry  GSW   34682550.0
# 1           2    LeBron James  CLE   33285709.0
# 2           3    Paul Millsap  DEN   31269231.0
# 3           4  Gordon Hayward  BOS   29727900.0
# 4           5   Blake Griffin  DET   29512900.0

# %%
df3 = pd.read_csv('Seasons_Stats.csv')

# %%
stats = df3

# %%
df3.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %% [markdown]
# # Data Aggregation

# %% [markdown]
# The three datasets contain distinct data, each containing certain columns that primarily include player information. Specifically, the NBA_season1718_salary dataset provides salary details for the 2018 season, while the players dataset contains information about individual players. The season dataset, on the other hand, encompasses season-wise data dating back to 1950. To conduct an analysis, it is necessary to merge data from all three datasets. The analysis can be player-wise or season-wise, with the focus being on a regression problem. Initially, the analysis will concentrate on player-wise investigation to predict player salaries. As we have access to salary information for just one season, we must gather information about the 2016 season and the details of all players drafted in 2017.

# %%
df1 = df1.rename(columns={'name': 'Player'})

# %%
df1.head()
# Out:
#                 Player  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
merged_data = pd.merge(df2, df1, on='Player',how = 'inner')

# %%
merged_data
# Out:
#      Unnamed: 0           Player   Tm  season17_18  year_start  year_end  \
# 0             1    Stephen Curry  GSW   34682550.0        2010      2018
# 1             2     LeBron James  CLE   33285709.0        2004      2018
# 2             3     Paul Millsap  DEN   31269231.0        2007      2018
# 3             4   Gordon Hayward  BOS   29727900.0        2011      2018
# 4             5    Blake Griffin  DET   29512900.0        2011      2018
# ..          ...              ...  ...          ...         ...       ...
# 553         566  Marcus Thornton  CLE      46080.0        2010      2017
# 554         568     Axel Toupane  NOP      25000.0        2016      2017
# 555         570    Chris Johnson  HOU      25000.0        2011      2013
# 556         570    Chris Johnson  HOU      25000.0        2013      2016
# 557         571       Beno Udrih  DET      25000.0        2005      2017
#
#     position height  weight         birth_date                     college
# 0          G    6-3   190.0     March 14, 1988            Davidson College
# 1        F-G    6-8   250.0  December 30, 1984                         NaN
# 2          F    6-8   246.0  February 10, 1985   Louisiana Tech University
# 3        F-G    6-8   226.0     March 23, 1990           Butler University
# 4          F   6-10   251.0     March 16, 1989      University of Oklahoma
# ..       ...    ...     ...                ...                         ...
# 553        G    6-4   205.0       June 5, 1987  Louisiana State University
# 554      G-F    6-7   197.0      July 23, 1992                         NaN
# 555        C   6-11   210.0      July 15, 1985  Louisiana State University
# 556      F-G    6-6   206.0     April 29, 1990        University of Dayton
# 557        G    6-3   205.0       July 5, 1982                         NaN
#
# [558 rows x 11 columns]

# %% [markdown]
# I have merged palyer infomation with Salary data set on Players column

# %%
merged_data.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Tm', 'season17_18', 'year_start', 'year_end',
#        'position', 'height', 'weight', 'birth_date', 'college'],
#       dtype='object')

# %%
merged_data  = merged_data.drop(['Unnamed: 0'] ,axis = 1)

# %%
merged_data.head()
# Out:
#            Player   Tm  season17_18  year_start  year_end position height  \
# 0   Stephen Curry  GSW   34682550.0        2010      2018        G    6-3
# 1    LeBron James  CLE   33285709.0        2004      2018      F-G    6-8
# 2    Paul Millsap  DEN   31269231.0        2007      2018        F    6-8
# 3  Gordon Hayward  BOS   29727900.0        2011      2018      F-G    6-8
# 4   Blake Griffin  DET   29512900.0        2011      2018        F   6-10
#
#    weight         birth_date                    college
# 0   190.0     March 14, 1988           Davidson College
# 1   250.0  December 30, 1984                        NaN
# 2   246.0  February 10, 1985  Louisiana Tech University
# 3   226.0     March 23, 1990          Butler University
# 4   251.0     March 16, 1989     University of Oklahoma

# %%
df = merged_data

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# The merged data set has many features which need further Processing , Like we Height given as String.
# In every sports Age and Experience Play important role. So we will find age and Experience from the given clumns.
# Age at the time of draft that is in 2018 , can be found by subtracting bith date from draft year.
# Also Experince can be found by subtracting start date from currrent date

# %%
#Converting birth date to date time fotrmat.
df['birth_date'] = df['birth_date'].apply(lambda x : datetime.strptime(x, '%B %d, %Y'))

# %%
df.head()
# Out:
#            Player   Tm  season17_18  year_start  year_end position height  \
# 0   Stephen Curry  GSW   34682550.0        2010      2018        G    6-3
# 1    LeBron James  CLE   33285709.0        2004      2018      F-G    6-8
# 2    Paul Millsap  DEN   31269231.0        2007      2018        F    6-8
# 3  Gordon Hayward  BOS   29727900.0        2011      2018      F-G    6-8
# 4   Blake Griffin  DET   29512900.0        2011      2018        F   6-10
#
#    weight birth_date                    college
# 0   190.0 1988-03-14           Davidson College
# 1   250.0 1984-12-30                        NaN
# 2   246.0 1985-02-10  Louisiana Tech University
# 3   226.0 1990-03-23          Butler University
# 4   251.0 1989-03-16     University of Oklahoma

# %%
# Finding the age

# %%
from datetime import datetime
year = datetime(2017, 1, 1)

# %%
df['age'] = df['birth_date'].apply(lambda x : year - x)

# %%
df.head()
# Out:
#            Player   Tm  season17_18  year_start  year_end position height  \
# 0   Stephen Curry  GSW   34682550.0        2010      2018        G    6-3
# 1    LeBron James  CLE   33285709.0        2004      2018      F-G    6-8
# 2    Paul Millsap  DEN   31269231.0        2007      2018        F    6-8
# 3  Gordon Hayward  BOS   29727900.0        2011      2018      F-G    6-8
# 4   Blake Griffin  DET   29512900.0        2011      2018        F   6-10
#
#    weight birth_date                    college        age
# 0   190.0 1988-03-14           Davidson College 10520 days
# 1   250.0 1984-12-30                        NaN 11690 days
# 2   246.0 1985-02-10  Louisiana Tech University 11648 days
# 3   226.0 1990-03-23          Butler University  9781 days
# 4   251.0 1989-03-16     University of Oklahoma 10153 days

# %%
# Converting days to Years

# %%
df['age'] = df['age'].apply(lambda x : x/365)

# %%
type(df['age'].values[1])
# Out:
# numpy.timedelta64

# %%
df['age'] = df['age'].apply(lambda x : str(x))

# %%
df['age'] = df['age'].apply(lambda x : x.split()[0])

# %%
df['age'] = df['age'].apply(lambda x :  int(x))

# %%
df.head()
# Out:
#            Player   Tm  season17_18  year_start  year_end position height  \
# 0   Stephen Curry  GSW   34682550.0        2010      2018        G    6-3
# 1    LeBron James  CLE   33285709.0        2004      2018      F-G    6-8
# 2    Paul Millsap  DEN   31269231.0        2007      2018        F    6-8
# 3  Gordon Hayward  BOS   29727900.0        2011      2018      F-G    6-8
# 4   Blake Griffin  DET   29512900.0        2011      2018        F   6-10
#
#    weight birth_date                    college  age
# 0   190.0 1988-03-14           Davidson College   28
# 1   250.0 1984-12-30                        NaN   32
# 2   246.0 1985-02-10  Louisiana Tech University   31
# 3   226.0 1990-03-23          Butler University   26
# 4   251.0 1989-03-16     University of Oklahoma   27

# %%
df.isnull().sum()
# Out:
# Player          0
# Tm              0
# season17_18     0
# year_start      0
# year_end        0
# position        0
# height          0
# weight          0
# birth_date      0
# college        96
# age             0
# dtype: int64

# %%
df = df.dropna(how='any')

# %%
df.isnull().sum()
# Out:
# Player         0
# Tm             0
# season17_18    0
# year_start     0
# year_end       0
# position       0
# height         0
# weight         0
# birth_date     0
# age            0
# dtype: int64

# %%
df.head()
# Out:
#            Player   Tm  season17_18  year_start  year_end position height  \
# 0   Stephen Curry  GSW   34682550.0        2010      2018        G    6-3
# 1    LeBron James  CLE   33285709.0        2004      2018      F-G    6-8
# 2    Paul Millsap  DEN   31269231.0        2007      2018        F    6-8
# 3  Gordon Hayward  BOS   29727900.0        2011      2018      F-G    6-8
# 4   Blake Griffin  DET   29512900.0        2011      2018        F   6-10
#
#    weight birth_date  age
# 0   190.0 1988-03-14   28
# 1   250.0 1984-12-30   32
# 2   246.0 1985-02-10   31
# 3   226.0 1990-03-23   26
# 4   251.0 1989-03-16   27

# %%
# Finding The experience for each player

# %%
df['Exp'] = df['year_start'].apply(lambda x : 2018 - x )

# %%
df.head()
# Out:
#            Player   Tm  season17_18  year_start  year_end position height  \
# 0   Stephen Curry  GSW   34682550.0        2010      2018        G    6-3
# 1    LeBron James  CLE   33285709.0        2004      2018      F-G    6-8
# 2    Paul Millsap  DEN   31269231.0        2007      2018        F    6-8
# 3  Gordon Hayward  BOS   29727900.0        2011      2018      F-G    6-8
# 4   Blake Griffin  DET   29512900.0        2011      2018        F   6-10
#
#    weight birth_date  age  Exp
# 0   190.0 1988-03-14   28    8
# 1   250.0 1984-12-30   32   14
# 2   246.0 1985-02-10   31   11
# 3   226.0 1990-03-23   26    7
# 4   251.0 1989-03-16   27    7

# %%
# Droping unnessacery columns.

# %%
df = df.drop(['year_start','year_end','birth_date'],axis=1)

# %%
df.head()
# Out:
#            Player   Tm  season17_18 position height  weight  age  Exp
# 0   Stephen Curry  GSW   34682550.0        G    6-3   190.0   28    8
# 1    LeBron James  CLE   33285709.0      F-G    6-8   250.0   32   14
# 2    Paul Millsap  DEN   31269231.0        F    6-8   246.0   31   11
# 3  Gordon Hayward  BOS   29727900.0      F-G    6-8   226.0   26    7
# 4   Blake Griffin  DET   29512900.0        F   6-10   251.0   27    7

# %% [markdown]
# ##  Height Variable

# %% [markdown]
# Given Height is in string format , 6-3 which means its 6 feet 3 inch.
# So we will convert it into centimerters , Since that will be easy to represent.
# Firt we will split the height on '-', Then seperate feet and inch value.After this we will convert them into cm using formulla :
# 1 feet  = 30.68
# 1 inch = 2.54
# Finally we will add these values and make a single column height_cm

# %%
type(df['height'].values[1])
# Out:
# str

# %%
df['feet'] = df['height'].apply(lambda x : x.split('-')[0])

# %%
df.head()
# Out:
#            Player   Tm  season17_18 position height  weight  age  Exp feet
# 0   Stephen Curry  GSW   34682550.0        G    6-3   190.0   28    8    6
# 1    LeBron James  CLE   33285709.0      F-G    6-8   250.0   32   14    6
# 2    Paul Millsap  DEN   31269231.0        F    6-8   246.0   31   11    6
# 3  Gordon Hayward  BOS   29727900.0      F-G    6-8   226.0   26    7    6
# 4   Blake Griffin  DET   29512900.0        F   6-10   251.0   27    7    6

# %%
df['inch'] = df['height'].apply(lambda x : x.split('-')[1])

# %%
df.head()
# Out:
#            Player   Tm  season17_18 position height  weight  age  Exp feet  \
# 0   Stephen Curry  GSW   34682550.0        G    6-3   190.0   28    8    6
# 1    LeBron James  CLE   33285709.0      F-G    6-8   250.0   32   14    6
# 2    Paul Millsap  DEN   31269231.0        F    6-8   246.0   31   11    6
# 3  Gordon Hayward  BOS   29727900.0      F-G    6-8   226.0   26    7    6
# 4   Blake Griffin  DET   29512900.0        F   6-10   251.0   27    7    6
#
#   inch
# 0    3
# 1    8
# 2    8
# 3    8
# 4   10

# %%
df['height_cms'] = df['feet'].apply(lambda x : int(x)*30.48) + df['inch'].apply(lambda x : int(x)*2.54)

# %%
df = df.drop(['inch','height','feet'],axis = 1)

# %%
df.head()
# Out:
#            Player   Tm  season17_18 position  weight  age  Exp  height_cm
# 0   Stephen Curry  GSW   34682550.0        G   190.0   28    8     190.50
# 1    LeBron James  CLE   33285709.0      F-G   250.0   32   14     203.20
# 2    Paul Millsap  DEN   31269231.0        F   246.0   31   11     203.20
# 3  Gordon Hayward  BOS   29727900.0      F-G   226.0   26    7     203.20
# 4   Blake Griffin  DET   29512900.0        F   251.0   27    7     208.28

# %%
df.shape
# Out:
# (513, 8)

# %% [markdown]
# The salary of Player in the next season might be impacted how well they performed in previous season, Since we have data about all the season , we will take points column for year 2016 for each player and merge the data set with our data set

# %%
ss = pd.read_csv('Seasons_Stats.csv')

# %%
ss = ss[(ss['Year'] == 2016)]

# %%
ss = ss.loc[:, ['Player', 'PTS']]

# %%
ss.columns
# Out:
# Index(['Player', 'PTS'], dtype='object')

# %%
common_values = pd.Series(list(set(df['Player']).intersection(set(ss['Player']))))

# %%
df = pd.merge(df, ss, on='Player',how = 'inner')

# %%
df.shape
# Out:
# (562, 9)

# %%
df.head()
# Out:
#            Player   Tm  season17_18 position  weight  age  Exp  height_cm  \
# 0   Stephen Curry  GSW   34682550.0        G   190.0   28    8     190.50
# 1    LeBron James  CLE   33285709.0      F-G   250.0   32   14     203.20
# 2    Paul Millsap  DEN   31269231.0        F   246.0   31   11     203.20
# 3  Gordon Hayward  BOS   29727900.0      F-G   226.0   26    7     203.20
# 4   Blake Griffin  DET   29512900.0        F   251.0   27    7     208.28
#
#       PTS
# 0  2375.0
# 1  1920.0
# 2  1385.0
# 3  1578.0
# 4   749.0

# %%
null_scores = df.loc[data['PTS'].isnull(), 'Player']

# %%
null_scores
# Out:
# Series([], Name: Player, dtype: object)

# %%
df.shape
# Out:
# (562, 9)

# %% [markdown]
# # EDA

# %%
df.describe()
# Out:
#         season17_18      weight         age         Exp   height_cm  \
# count  5.620000e+02  562.000000  562.000000  562.000000  562.000000
# mean   6.087481e+06  218.690391   25.896797    5.379004  200.678078
# std    7.145276e+06   25.882228    4.467353    4.499608    8.878170
# min    1.722400e+04  150.000000   18.000000    0.000000  175.260000
# 25%    1.312611e+06  200.000000   22.000000    1.250000  193.040000
# 50%    2.692080e+06  220.000000   26.000000    4.000000  200.660000
# 75%    8.000000e+06  239.000000   29.000000    9.000000  208.280000
# max    3.468255e+07  307.000000   40.000000   20.000000  220.980000
#
#                PTS
# count   562.000000
# mean    613.213198
# std     379.971014
# min       0.000000
# 25%     365.250000
# 50%     613.213198
# 75%     702.250000
# max    2376.000000

# %%
df.dtypes
# Out:
# Player          object
# Tm              object
# season17_18    float64
# position        object
# weight         float64
# age              int64
# Exp              int64
# height_cm      float64
# dtype: object

# %%
# Dropping the Index column , Player

# %%
df = df.drop(['Player'],axis = 1)

# %%
df.columns
# Out:
# Index(['Tm', 'season17_18', 'position', 'weight', 'age', 'Exp', 'height_cm',
#        'PTS'],
#       dtype='object')

# %% [markdown]
# # Age distribution

# %%
plt.hist(df["age"], color="green")
plt.title("NBA Player Age")
plt.xlabel("age")
plt.ylabel("count")
plt.axvline(df['age'].mean(), color='r', linestyle='dashed')
plt.plot()
# Out:
# []

# %%
sns.displot(df,x = df['age'],kind = 'kde', color="green")

# %% [markdown]
# Most players fell between an age range of 22 to 30 years old, and the average player is 27 years old. This speaks to the longevity of careers in the NBA; most people do not end up playing for more than five to eight years.

# %%
plt.hist(df["weight"], color="purple")
plt.title("NBA Player Weight")
plt.xlabel("Weight (lbs)")
plt.ylabel("count")
plt.axvline(df['weight'].mean(), color='r', linestyle='dashed')
plt.plot()
# Out:
# []

# %% [markdown]
# Most of our players weigh between 80 and 120 kg (175 to 265 lbs) and the average weight was about 95 kg.

# %%
sns.displot(df,x = df["weight"],kind = 'kde',color="purple")

# %%
plt.hist(df["height_cm"], color="blue")
plt.title("NBA Player Height")
plt.xlabel("Height (cm)")
plt.ylabel("count")
plt.axvline(df['height_cm'].mean(), color='r', linestyle='dashed')
plt.plot()
# Out:
# []

# %%
sns.displot(df,x = df["height_cm"],kind = 'kde',color="blue")

# %% [markdown]
# The majority of players fell into a height range of 190 cm to 210 cm (6'2" to 6'10"), and the average player is roughly 200 cm tall.

# %%
plt.hist(df["Exp"], color="magenta")
plt.title("NBA Player Experience")
plt.xlabel("Experience")
plt.ylabel("count")
plt.axvline(df['Exp'].mean(), color='r', linestyle='dashed')
plt.plot()
# Out:
# []

# %%
sns.displot(df,x = df["Exp"],kind = 'kde',color="magenta")

# %% [markdown]
# The average experience is around 5 years , From the graph we can tell Most Players have a carrier of 4 to 8 years

# %% [markdown]
# # Target Varaible analysis

# %%
plt.hist(df["season17_18"], color="orange")
plt.title("NBA Player Salary")
plt.xlabel("Salary")
plt.ylabel("count")
plt.axvline(df['season17_18'].mean(), color='r', linestyle='dashed')
plt.plot()
# Out:
# []

# %%
sns.displot(df,x = df["season17_18"],kind = 'kde',color="orange")

# %% [markdown]
# Salary Column is Highly Skwed, with a mean salary of around 5 millions.

# %%
plt.figure(figsize=(13,6))
avg_salary = df['season17_18'].mean()

# Create subsets of the data
greater_than_avg = df[df['season17_18'] > avg_salary]
less_than_avg = df[df['season17_18'] < avg_salary]

# Count the number of players in each subset
num_greater = greater_than_avg.shape[0]
num_less = less_than_avg.shape[0]

# Create a bar chart showing the number of players in each salary category
plt.bar(['Greater than Avg', 'Less than Avg'], [num_greater, num_less])
plt.title('Salary Distribution')
plt.xlabel('Salary Category')
plt.ylabel('Number of Players')
plt.show()

# %% [markdown]
# From the above bar grapgh we can see the pay disparity among players while most of the Players are earning below average salary. While a Very Few Players have salary greater than Averge Salary.

# %% [markdown]
# # Bi-variant analysis

# %%
plt.figure(figsize=(13,6))
sns.set_style
sns.scatterplot(x=df['season17_18'], y=df['Exp'], color = 'g')
plt.xlabel('Salary')
plt.ylabel('Experience')
plt.title('Salary VS Experience')# Save graph
plt.show()

# %% [markdown]
# Above graphs indicate there is a positive co-relation between Salary and experience

# %%
plt.figure(figsize=(13,6))
sns.set_style("darkgrid")

sns.scatterplot(x=df['season17_18'], y=df['PTS'],color = 'b')
plt.xlabel('Salary')
plt.ylabel('Points')
plt.title('Salary VS Points')# Save graph
plt.show()

# %% [markdown]
# The number of points scored in Previous Season has clearny an impact on salary, as the Graph indicates a strong Positive Corelation

# %%
plt.figure(figsize=(13,6))
sns.set_style("darkgrid")

sns.scatterplot(x=df['season17_18'], y=df['age'],color = 'c')
plt.xlabel('Salary')
plt.ylabel('age')
plt.title('Salary VS Age')# Save graph
plt.show()

# %% [markdown]
# In case of age salry increase upto certain age , Then again salary for higher ages above 35 seems to be significantly decreasing.

# %%
plt.figure(figsize=(13,6))
sns.set_style("darkgrid")
sns.scatterplot(x=df['season17_18'], y=df['height_cm'],color = 'k')
plt.xlabel('Salary')
plt.ylabel('Height')
plt.title('Salary VS Height')# Save graph
plt.show()

# %% [markdown]
# Height doesn't seem to have too much of a effect on Salary

# %%
corr_matrix = df.corr()

sns.heatmap(corr_matrix, annot=True, cmap='RdBu_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Categorical Columns

# %%
sns.set_style("darkgrid")
ax = sns.countplot(x="position", data=df, palette="cool")

# Set labels and title
ax.set_title("Count of Position of Play", fontsize=16)
ax.set_xlabel("Position", fontsize=14)
ax.set_ylabel("Count", fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# Most of the Players Play at Gaurd Position and Forward Position

# %% [markdown]
# We will try to find if Height has any effect on which Poaition a Player Plays

# %%
sns.set_style("darkgrid")
sns.displot(df,x=df['height_cm'], hue = 'position',color = 'k')
plt.xlabel('Height')
plt.ylabel('count')
plt.title('Position VS Height')
plt.show()

# %% [markdown]
# Most of the Players who have Height grater Than 200 cm play central positions.
# While Players with Height less than 190 play mostly at Guard.

# %%
sns.set_style("darkgrid")
sns.displot(df,x=df['PTS'] ,kind = 'kde' , hue = 'position',color = 'k')
plt.xlabel('Points')
plt.ylabel('count')
plt.title('Position VS Points')
plt.show()

# %% [markdown]
# Distribution of Points for each Position is Similar.

# %%
sns.set_style("darkgrid")
sns.displot(df,x=df['Exp'] ,kind = 'kde', hue = 'position',color = 'k')
plt.xlabel('Experience')
plt.ylabel('count')
plt.title('Position VS Experience')
plt.show()

# %% [markdown]
# Plyers with more Experience mostly play central and Forward positions

# %% [markdown]
# # Team Variable

# %% [markdown]
# We will try to find the salary for each team.

# %%
avg_salary = df.groupby('Tm')['season17_18'].mean().reset_index()

# Create a bar plot
plt.figure(figsize=(20, 20))
plt.bar(avg_salary['Tm'], avg_salary['season17_18'],color = 'green')
plt.title('Average Salary per Team', fontsize=16)
plt.xlabel('Team', fontsize=14)
plt.axhline(y = avg_salary['season17_18'].mean(), color='r', linestyle='dashed')
plt.ylabel('Average Salary Per Team', fontsize=14)
plt.show()

# %% [markdown]
# Finding the average points scored by each team

# %%
avg_points = df.groupby('Tm')['PTS'].mean().reset_index()

# Create a bar plot
plt.figure(figsize=(20, 20))
plt.bar(avg_salary['Tm'], avg_points['PTS'],color = 'blue')
plt.title('Average Points per Team', fontsize=16)
plt.xlabel('Team', fontsize=14)
plt.axhline(y = avg_points['PTS'].mean(), color='r', linestyle='dashed')
plt.ylabel('Average Points per team', fontsize=14)
plt.show()

# %% [markdown]
# Creating a new data set which has average salary and average points for each team.
# We will try to find teams who payed more than average and scored less than average points per team.
# And teams who payed less than avergae and scored more than average points in season.

# %%
merged_data = pd.merge(avg_salary, avg_points, on='Tm',how = 'inner')

# %%
merged_data
# Out:
#      Tm   season17_18         PTS
# 0   ATL  4.010674e+06  530.741399
# 1   BOS  7.655598e+06  773.218613
# 2   BRK  5.904092e+06  555.164975
# 3   CHI  3.600986e+06  470.291547
# 4   CHO  8.373440e+06  732.933285
# 5   CLE  7.867479e+06  774.245911
# 6   DAL  4.284156e+06  607.545939
# 7   DEN  6.876870e+06  723.537733
# 8   DET  5.301253e+06  460.722640
# 9   GSW  7.743616e+06  720.813311
# 10  HOU  5.164276e+06  664.698521
# 11  IND  5.137186e+06  615.513959
# 12  LAC  6.302152e+06  566.928299
# 13  LAL  5.716724e+06  692.615180
# 14  MEM  6.186848e+06  545.971799
# 15  MIA  7.290146e+06  600.880711
# 16  MIL  5.643209e+06  611.309161
# 17  MIN  6.937746e+06  719.483129
# 18  NOP  6.545799e+06  599.515510
# 19  NYK  6.141549e+06  549.547256
# 20  OKC  8.952937e+06  726.109306
# 21  ORL  6.371117e+06  507.191558
# 22  PHI  4.627224e+06  565.304799
# 23  PHO  4.679057e+06  597.204949
# 24  POR  5.854077e+06  553.622190
# 25  SAC  4.821280e+06  536.192893
# 26  SAS  7.194897e+06  770.129124
# 27  TOR  7.280170e+06  674.405774
# 28  UTA  6.622515e+06  636.642449
# 29  WAS  6.863326e+06  558.421562

# %%
count_below_avg = merged_data[(merged_data['season17_18'] < merged_data['season17_18'].mean()) & (merged_data['PTS'] > merged_data['PTS'].mean())]

# %%
count_below_avg
# Out:
#      Tm   season17_18         PTS
# 10  HOU  5.164276e+06  664.698521
# 13  LAL  5.716724e+06  692.615180

# %%
 count_above_avg = merged_data[(merged_data['season17_18'] > merged_data['season17_18'].mean()) & (merged_data['PTS'] < merged_data['PTS'].mean())]

# %%
count_above_avg.shape
# Out:
# (5, 3)

# %%
plt.figure(figsize=(20, 7))
plt.bar(['Salary_below_average_and_points_above_avg','Salary_above_average_and_points_below_avg'], [count_below_avg.shape[0], count_above_avg.shape[0]])
plt.title('Salary Distribution')
plt.xlabel('Number of Teams')
plt.ylabel('Count')
plt.show()

# %%
stats = pd.read_csv("Seasons_Stats.csv")

# %%
stats.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
stats.shape
# Out:
# (24691, 53)

# %%
stats.isnull().sum()
# Out:
# Unnamed: 0        0
# Year             67
# Player           67
# Pos              67
# Age              75
# Tm               67
# G                67
# GS             6458
# MP              553
# PER             590
# TS%             153
# 3PAr           5852
# FTr             166
# ORB%           3899
# DRB%           3899
# TRB%           3120
# AST%           2136
# STL%           3899
# BLK%           3899
# TOV%           5109
# USG%           5051
# blanl         24691
# OWS             106
# DWS             106
# WS              106
# WS/48           590
# blank2        24691
# OBPM           3894
# DBPM           3894
# BPM            3894
# VORP           3894
# FG               67
# FGA              67
# FG%             166
# 3P             5764
# 3PA            5764
# 3P%            9275
# 2P               67
# 2PA              67
# 2P%             195
# eFG%            166
# FT               67
# FTA              67
# FT%             925
# ORB            3894
# DRB            3894
# TRB             379
# AST              67
# STL            3894
# BLK            3894
# TOV            5046
# PF               67
# PTS              67
# dtype: int64

# %%
stats.shape
# Out:
# (24691, 53)

# %%
players = pd.read_csv('player_data.csv')

# %%
players.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
players.shape
# Out:
# (4550, 8)

# %%
players = players.rename(columns={'name': 'Player'})

# %%
players.head()
# Out:
#                 Player  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
players.dtypes
# Out:
# Player         object
# year_start      int64
# year_end        int64
# position       object
# height         object
# weight        float64
# birth_date     object
# college        object
# dtype: object

# %%
players.set_index('Player', inplace=True)

# %%
players.head()
# Out:
#                      year_start  year_end position height  weight  \
# Player
# Alaa Abdelnaby             1991      1995      F-C   6-10   240.0
# Zaid Abdul-Aziz            1969      1978      C-F    6-9   235.0
# Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# Mahmoud Abdul-Rauf         1991      2001        G    6-1   162.0
# Tariq Abdul-Wahad          1998      2003        F    6-6   223.0
#
#                            birth_date                                college
# Player
# Alaa Abdelnaby          June 24, 1968                        Duke University
# Zaid Abdul-Aziz         April 7, 1946                  Iowa State University
# Kareem Abdul-Jabbar    April 16, 1947  University of California, Los Angeles
# Mahmoud Abdul-Rauf      March 9, 1969             Louisiana State University
# Tariq Abdul-Wahad    November 3, 1974              San Jose State University

# %%
complete_stats = stats.join(players, on="Player")

# %%
complete_stats.shape
# Out:
# (25297, 60)

# %%
df = complete_stats

# %%
df.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...  TOV     PF    PTS  year_start  year_end  position  height  weight  \
# 0  ...  NaN  217.0  458.0      1949.0    1951.0       G-F    5-11   170.0
# 1  ...  NaN   99.0  279.0      1950.0    1952.0         G     6-2   185.0
# 2  ...  NaN  192.0  438.0      1950.0    1954.0       F-G     6-4   190.0
# 3  ...  NaN   29.0   63.0      1950.0    1951.0         F     6-5   195.0
# 4  ...  NaN   27.0   59.0      1950.0    1951.0         F     6-5   195.0
#
#          birth_date                          college
# 0  November 1, 1918               Indiana University
# 1  January 15, 1921           University of Kentucky
# 2      May 11, 1924         University of Notre Dame
# 3   October 8, 1925  North Carolina State University
# 4   October 8, 1925  North Carolina State University
#
# [5 rows x 60 columns]

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df.head()
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...  \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#    TOV     PF    PTS  year_start  year_end  position  height  weight  \
# 0  NaN  217.0  458.0      1949.0    1951.0       G-F    5-11   170.0
# 1  NaN   99.0  279.0      1950.0    1952.0         G     6-2   185.0
# 2  NaN  192.0  438.0      1950.0    1954.0       F-G     6-4   190.0
# 3  NaN   29.0   63.0      1950.0    1951.0         F     6-5   195.0
# 4  NaN   27.0   59.0      1950.0    1951.0         F     6-5   195.0
#
#          birth_date                          college
# 0  November 1, 1918               Indiana University
# 1  January 15, 1921           University of Kentucky
# 2      May 11, 1924         University of Notre Dame
# 3   October 8, 1925  North Carolina State University
# 4   October 8, 1925  North Carolina State University
#
# [5 rows x 59 columns]

# %%
df = df[df.Year >= 1990]

# %%
df.head()
# Out:
#         Year         Player Pos   Age   Tm     G    GS      MP   PER    TS%  \
# 9547  1990.0     Mark Acres   C  27.0  ORL  80.0  50.0  1691.0   8.3  0.536
# 9548  1990.0  Michael Adams  PG  27.0  DEN  79.0  74.0  2690.0  15.4  0.542
# 9549  1990.0   Mark Aguirre  SF  30.0  DET  78.0  40.0  2005.0  15.8  0.544
# 9550  1990.0    Danny Ainge  PG  30.0  SAC  75.0  68.0  2727.0  16.1  0.528
# 9551  1990.0    Mark Alarie  PF  26.0  WSB  82.0  10.0  1893.0  14.1  0.510
#
#       ...    TOV     PF     PTS  year_start  year_end  position  height  \
# 9547  ...   70.0  248.0   362.0      1988.0    1993.0       F-C    6-11
# 9548  ...  141.0  133.0  1221.0      1986.0    1996.0         G    5-10
# 9549  ...  121.0  201.0  1099.0      1982.0    1994.0       F-G     6-6
# 9550  ...  185.0  238.0  1342.0      1982.0    1995.0         G     6-4
# 9551  ...  101.0  219.0   860.0      1987.0    1991.0         F     6-8
#
#       weight         birth_date                   college
# 9547   220.0  November 15, 1962   Oral Roberts University
# 9548   162.0   January 19, 1963            Boston College
# 9549   232.0  December 10, 1959         DePaul University
# 9550   175.0     March 17, 1959  Brigham Young University
# 9551   217.0  December 11, 1963           Duke University
#
# [5 rows x 59 columns]

# %%
df.columns
# Out:
# Index(['Year', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr',
#        'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
#        'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2', 'OBPM', 'DBPM', 'BPM',
#        'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%',
#        'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'PTS', 'year_start', 'year_end', 'position', 'height',
#        'weight', 'birth_date', 'college'],
#       dtype='object')

# %%
df = df.drop(['Age', 'college','year_start', 'year_end'],axis = 1)

# %%
df['feet'] = df['height'].apply(lambda x : x.split('-')[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5653/2929339258.py in <module>
# ----> 1 df['feet'] = df['height'].apply(lambda x : x.split('-')[0])
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_5653/2929339258.py in <lambda>(x)
# ----> 1 df['feet'] = df['height'].apply(lambda x : x.split('-')[0])
#
# AttributeError: 'float' object has no attribute 'split'

# %%
df['height_cms'] = df['feet'].apply(lambda x : int(x)*30.48) + df['inch'].apply(lambda x : int(x)*2.54)
df = df.drop(['inch','height','feet'],axis = 1)
# Out:
#   File "/tmp/ipykernel_5653/560270885.py", line 2
#     df = df.drop(['inch','height','feet'],axis = 1
#                                                   ^
# SyntaxError: unexpected EOF while parsing

# %%
type(df['height'].values[1])
# Out:
# str

# %%
df.isnull().sum()
# Out:
# Year              0
# Pos               0
# Tm                0
# G                 0
# GS                0
# MP                0
# PER               5
# TS%              72
# 3PAr             81
# FTr              81
# ORB%              5
# DRB%              5
# TRB%              5
# AST%              5
# STL%              5
# BLK%              5
# TOV%             59
# USG%              5
# blanl         14998
# OWS               0
# DWS               0
# WS                0
# WS/48             5
# blank2        14998
# OBPM              0
# DBPM              0
# BPM               0
# VORP              0
# FG                0
# FGA               0
# FG%              81
# 3P                0
# 3PA               0
# 3P%            2676
# 2P                0
# 2PA               0
# 2P%             109
# eFG%             81
# FT                0
# FTA               0
# FT%             660
# ORB               0
# DRB               0
# TRB               0
# AST               0
# STL               0
# BLK               0
# TOV               0
# PF                0
# PTS               0
# position          0
# weight            0
# birth_date        0
# height_cms        0
# dtype: int64

# %%
df = df.drop(['blanl','blank2', '3P%'], axis = 1)

# %%
df = df.dropna(how = 'any')

# %% [markdown]
# We want to move the player names into their own parallel DataFrame so that their qualitative nature does not interfere with our analyses.Since the original DataFrame has both quantitative data (numbers that can be analyzed mathematically) and qualitative data (descriptions or names that cannot be analyzed mathematically), and the goal is to separate the qualitative data (player names) into a new DataFrame so that it does not affect the analysis of the quantitative data.
#
# By creating a new DataFrame for just the player names, the original DataFrame will now only contain the quantitative data, which can be analyzed mathematically without being affected by the presence of non-numeric data. This can help ensure that any statistical or mathematical analyses performed on the data are accurate and not influenced by the presence of non-numeric data.

# %%
df_with_names = df.copy()

player_names = df[['id', 'name']]
trimmed_stats.drop(axis=1, labels=['name'], inplace=True)
trimmed_stats.head()

# %%
df = df.groupby("Year").mean().reset_index()

# %%
df.head()
# Out:
#      Year          G         GS           MP        PER       TS%      3PAr  \
# 0  2000.0  51.041494  23.373444  1167.560166  12.159129  0.492400  0.157203
# 1  2001.0  49.325581  22.924419  1149.562016  11.994574  0.483944  0.152438
# 2  2002.0  50.652893  24.026860  1192.293388  12.502686  0.490545  0.167936
# 3  2003.0  51.790698  24.621564  1222.915433  11.942918  0.478150  0.160725
# 4  2004.0  47.036585  22.433798  1109.926829  11.945645  0.482244  0.160157
#
#         FTr      ORB%       DRB%  ...         DRB         TRB         AST  \
# 0  0.307465  6.104772  13.743154  ...  143.240664  202.624481  106.000000
# 1  0.300717  6.070155  13.992442  ...  143.315891  200.682171  101.655039
# 2  0.301134  5.985537  13.657438  ...  145.878099  205.873967  107.264463
# 3  0.299063  6.126427  13.607822  ...  151.822410  212.348837  106.363636
# 4  0.304544  5.822300  13.819861  ...  137.587108  192.594077   97.869338
#
#          STL        BLK        TOV          PF         PTS      weight  \
# 0  38.479253  23.153527  71.290456  114.358921  460.981328  215.589212
# 1  36.864341  23.895349  68.186047  108.250000  439.093023  216.137597
# 2  38.142562  25.033058  67.144628  105.597107  462.778926  217.826446
# 3  39.547569  24.558140  71.792812  110.955603  472.249471  219.270613
# 4  36.512195  22.653310  65.012195   99.371080  422.275261  219.365854
#
#    height_cms
# 0  200.254232
# 1  200.167752
# 2  200.166694
# 3  200.686850
# 4  200.898955
#
# [5 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['Year', 'G', 'GS', 'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%',
#        'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS',
#        'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'ORB', 'DRB', 'TRB', 'AST',
#        'STL', 'BLK', 'TOV', 'PF', 'PTS', 'weight', 'height_cms'],
#       dtype='object')
