# %%
import pandas as pd

# %%
df1 = pd.read_csv('Players.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %%
df1.shape
# Out:
# (3922, 8)

# %%
df2 = pd.read_csv('player_data.csv')

# %%
df2.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
df2.shape
# Out:
# (4550, 8)

# %%
df3 = pd.read_csv('NBA_season1718_salary.csv')

# %%
df3.head()
# Out:
#    Unnamed: 0          Player   Tm  season17_18
# 0           1   Stephen Curry  GSW   34682550.0
# 1           2    LeBron James  CLE   33285709.0
# 2           3    Paul Millsap  DEN   31269231.0
# 3           4  Gordon Hayward  BOS   29727900.0
# 4           5   Blake Griffin  DET   29512900.0

# %%
df3.shape
# Out:
# (573, 4)

# %%
df4 = pd.read_csv('Seasons_Stats.csv')

# %%
df4.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
res = df4[df4['Year'] == 2017]

# %%
res
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 24096       24096  2017.0       Alex Abrines  SG  23.0  OKC  68.0   6.0
# 24097       24097  2017.0         Quincy Acy  PF  26.0  TOT  38.0   1.0
# 24098       24098  2017.0         Quincy Acy  PF  26.0  DAL   6.0   0.0
# 24099       24099  2017.0         Quincy Acy  PF  26.0  BRK  32.0   1.0
# 24100       24100  2017.0       Steven Adams   C  23.0  OKC  80.0  80.0
# ...           ...     ...                ...  ..   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0
#
#            MP   PER  ...    FT%    ORB    DRB    TRB   AST   STL   BLK    TOV  \
# ...

# %%
import numpy as np

# %%
df5 = res[['Player','Tm']]

# %%
df6 = df3[['Player','Tm']]

# %%
df5.sort_index().sort_index(axis=1) == df6.sort_index().sort_index(axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5834/2798054230.py in <module>
# ----> 1 df5.sort_index().sort_index(axis=1) == df6.sort_index().sort_index(axis=1)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#      41
#      42     @unpack_zerodim_and_defer("__ne__")
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    6938         axis = 1  # only relevant for Series other case
# ...

# %%
df6["P","T"] =  df5.reset_index(drop=True) == df6.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('P', 'T')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df5 = np.where(df5['Player'] == df6['Player'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5834/3724419000.py in <module>
# ----> 1 df5 = np.where(df5['Player'] == df6['Player'])
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#      41
#      42     @unpack_zerodim_and_defer("__ne__")
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5615
#    5616         if isinstance(other, Series) and not self._indexed_same(other):
# ...

# %%
df5.head()
# Out:
#             Player   Tm
# 0  Curly Armstrong  FTW
# 1     Cliff Barker  INO
# 2    Leo Barnhorst  CHS
# 3       Ed Bartels  TOT
# 4       Ed Bartels  DNN

# %%
df6.head()
# Out:
#            Player   Tm
# 0   Stephen Curry  GSW
# 1    LeBron James  CLE
# 2    Paul Millsap  DEN
# 3  Gordon Hayward  BOS
# 4   Blake Griffin  DET

# %%
df5.equals(df6)
# Out:
# False

# %%
np.allclose(df5,df6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5834/771156600.py in <module>
# ----> 1 np.allclose(df5,df6)
#
# <__array_function__ internals> in allclose(*args, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py in allclose(a, b, rtol, atol, equal_nan)
#    2247
#    2248     """
# -> 2249     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2250     return bool(res)
#    2251
#
# <__array_function__ internals> in isclose(*args, **kwargs)
#
# ~/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2353         y = asanyarray(y, dtype=dt)
#    2354
# -> 2355     xfin = isfinite(x)
#    2356     yfin = isfinite(y)
#    2357     if all(xfin) and all(yfin):
#
# ...

# %%
from pandas.testing import assert_frame_equal

assert_frame_equal(df5, df6, check_dtype=False)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_5834/82110563.py in <module>
#       1 from pandas.testing import assert_frame_equal
#       2
# ----> 3 assert_frame_equal(df5, df6, check_dtype=False)
#
#     [... skipping hidden 2 frame]
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/testing.pyx in pandas._libs.testing.assert_almost_equal()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/testing.pyx in pandas._libs.testing.assert_almost_equal()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_testing/asserters.py in raise_assert_detail(obj, message, left, right, diff, index_values)
#     680         msg += f"\n[diff]: {diff}"
#     681
# --> 682     raise AssertionError(msg)
#     683
#     684
#
# AssertionError: DataFrame.index are different
#
# DataFrame.index values are different (100.0 %)
# ...

# %%
df5 = df5.iloc[:572,:]

# %%
df5.shape
# Out:
# (572, 2)

# %%
df6 = df6.iloc[:-1,:]

# %%
df6.shape
# Out:
# (572, 2)
